# %%
from api import get_cylinder
from utils import *

# %%
img = read_image('testcase/hongdian2.jpeg')
show_image(img)

# %%
flag, pos = get_cylinder(img)
print(flag, pos)
iii = img.copy()
cv2.circle(iii, pos, 10, (0, 255, 0), -1)
show_image(iii)
# Out:
# True (655, 320)
