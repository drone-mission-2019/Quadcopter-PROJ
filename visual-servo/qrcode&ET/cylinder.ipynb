# %%
from api import get_cylinder
from utils import *

# %%
img = read_image('testcase/xiaowuti.jpeg')
show_image(img)

# %%
flag, pos = get_cylinder(img)
print(flag, pos)
iii = img.copy()
cv2.circle(iii, pos, 10, (0, 255, 0), -1)
show_image(iii)
# Out:
# True (594.5, 316.5)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-9f324f2092bd> in <module>
#       2 print(flag, pos)
#       3 iii = img.copy()
# ----> 4 cv2.circle(iii, pos, 10, (0, 255, 0), -1)
#       5 show_image(iii)
#
# TypeError: integer argument expected, got float
