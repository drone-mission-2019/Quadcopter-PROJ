# %%
import cv2
from utils import *
import api
import matplotlib.pyplot as plt
import numpy as np
import os
from qr_code import get_qr_code

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
print('All testcases:')
testcases = []
for curdir, dirs, files in os.walk('testcase'):
    files.sort()
    for testcase in files:
        if testcase[:4] != 'test' or testcase[-3:] not in ['png', 'peg', 'jpg']:
            continue
        testcases.append(os.path.join(curdir, testcase))
print(testcases)
# Out:
# All testcases:
# ['testcase/test1.jpeg', 'testcase/test2.jpeg', 'testcase/test3.jpeg', 'testcase/test4.png', 'testcase/test5.jpeg', 'testcase/test6.png']

# %%
path = 'testcase/zed0.jpg'
# path = 'testcase/test1.jpeg'
img = read_image(path)
print(img.shape)
show_image(img)
# Out:
# (720, 1280, 3)

# %%
flag, center = get_qr_code(img)
print(flag)
print(center)
iii = img.copy()
cv2.circle(iii, center, 10, (0, 255, 0), -1)
show_image(iii)
# Out:
# [(54.0, (511.0, 364.0), [(537, 336), (485, 336), (485, 392), (538, 390)]), (53.004629232781554, (510.0, 106.0), [(537, 132), (537, 80), (483, 81), (485, 133)])]
# (511.0, 364.0) (510.0, 106.0) (485, 336) (0.00387593987797217, 0.9999924885168199) (0.6804510993672779, 0.7327934916262993) -0.6776057246537773
# True
# (510, 235)
