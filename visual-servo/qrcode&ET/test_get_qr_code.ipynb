# %%
import cv2
from utils import *
import api
import matplotlib.pyplot as plt
import numpy as np
import os

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
print('All testcases:')
testcases = []
for curdir, dirs, files in os.walk('testcase'):
    files.sort()
    for testcase in files:
        if testcase[:4] != 'test' or testcase[-3:] not in ['png', 'peg', 'jpg']:
            continue
        testcases.append(os.path.join(curdir, testcase))
print(testcases)
# Out:
# All testcases:
# ['testcase/test1.jpeg', 'testcase/test2.jpeg', 'testcase/test3.jpeg', 'testcase/test4.png', 'testcase/test5.jpeg', 'testcase/test6.png']

# %%
path = 'testcase/test5.jpeg'
img = read_image(path)
print(img.shape)
show_image(img)
# Out:
# (311, 418, 3)

# %%
qr_codes = api.get_qr_code(img)
img2 = img.copy()
for points in qr_codes:
    for i in range(4):
        p1 = points[i]
        p2 = points[i + 1] if i != 3 else points[0]
        cv2.line(img2, p1, p2, (0, 255, 0), 2)
show_image(img2)
